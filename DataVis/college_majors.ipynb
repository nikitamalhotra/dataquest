# %%
# American Community Survey 
# https://github.com/fivethirtyeight/data/tree/master/college-majors

# Do students in popular majors make more money?
# How many majors are predominantly male? predominantly female?
# Which category of majors have the most students?

# For after:
# Use a grouped bar plot to compare the number of men with the number of women in each category of majors.
# Use a box plot to explore the distributions of median salaries and unemployment rate.
# Use a hexagonal bin plot to visualize the columns that had dense scatter plots from earlier in the project.

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
recent_grads = pd.read_csv("Dataquest/DataVis/recent-grads.csv")

# %%
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Rank</th>
#       <th>Major_code</th>
#       <th>Major</th>
#       <th>Total</th>
#       <th>Men</th>
#       <th>Women</th>
#       <th>Major_category</th>
#       <th>ShareWomen</th>
#       <th>Sample_size</th>
#       <th>Employed</th>
#       <th>...</th>
#       <th>Part_time</th>
#       <th>Full_time_year_round</th>
#       <th>Unemployed</th>
#       <th>Unemployment_rate</th>
#       <th>Median</th>
#       <th>P25th</th>
#       <th>P75th</th>
#       <th>College_jobs</th>
#       <th>Non_college_jobs</th>
#       <th>Low_wage_jobs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
# ...

# %%
recent_grads.tail()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Rank</th>
#       <th>Major_code</th>
#       <th>Major</th>
#       <th>Total</th>
#       <th>Men</th>
#       <th>Women</th>
#       <th>Major_category</th>
#       <th>ShareWomen</th>
#       <th>Sample_size</th>
#       <th>Employed</th>
#       <th>...</th>
#       <th>Part_time</th>
#       <th>Full_time_year_round</th>
#       <th>Unemployed</th>
#       <th>Unemployment_rate</th>
#       <th>Median</th>
#       <th>P25th</th>
#       <th>P75th</th>
#       <th>College_jobs</th>
#       <th>Non_college_jobs</th>
#       <th>Low_wage_jobs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>168</th>
# ...

# %%
recent_grads.describe()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Rank</th>
#       <th>Major_code</th>
#       <th>Total</th>
#       <th>Men</th>
#       <th>Women</th>
#       <th>ShareWomen</th>
#       <th>Sample_size</th>
#       <th>Employed</th>
#       <th>Full_time</th>
#       <th>Part_time</th>
#       <th>Full_time_year_round</th>
#       <th>Unemployed</th>
#       <th>Unemployment_rate</th>
#       <th>Median</th>
#       <th>P25th</th>
#       <th>P75th</th>
#       <th>College_jobs</th>
#       <th>Non_college_jobs</th>
#       <th>Low_wage_jobs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>173.000000</td>
#       <td>173.000000</td>
# ...

# %%
raw_data_count = len(recent_grads)
print(raw_data_count)
# Out:
# 173

# %%
recent_grads.dropna(inplace=True)

# %%
cleaned_data_count = len(recent_grads)
print(cleaned_data_count)
# Out:
# 172

# %%
# Example of how to use df.plot()

# recent_grads.plot(x='Sample_size', y='Employed', kind='scatter', title='Employed vs. Sample_size', figsize=(5,10))
# ax = recent_grads.plot(x='Sample_size', y='Employed', kind='scatter')
# ax.set_title('Employed vs. Sample_size')

recent_grads.plot(x='Sample_size', y='Median', kind='scatter', title='Median Income vs. Sample Size')
recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter', title='Unemployment rate vs. Sample Size')
recent_grads.plot(x='Full_time', y='Median', kind='scatter', title='Median Income vs. # of Full Time Workers')
recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter', title='Unemployment Rate vs. % Women')
recent_grads.plot(x='Men', y='Median', kind='scatter', title='Median vs. # of Men')
recent_grads.plot(x='Women', y='Median', kind='scatter', title='Median vs. # of Women')

# %%
recent_grads['Sample_size'].hist()

# %%
recent_grads['Median'].hist()

# %%
recent_grads['Employed'].hist()

# %%
recent_grads['ShareWomen'].hist()

# %%
recent_grads['Unemployment_rate'].hist()

# %%
recent_grads['Men'].hist()

# %%
recent_grads['Women'].hist()

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10bb03ac8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10bfecb70>]], dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median', 'Unemployment_rate']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10af4df28>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c5f5278>]], dtype=object)

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen')

# %%
recent_grads[-10:].plot.bar(x='Major', y='ShareWomen')

# %%
recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate')

# %%
recent_grads[-10:].plot.bar(x='Major', y='Unemployment_rate')
