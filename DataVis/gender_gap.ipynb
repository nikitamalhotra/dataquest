# %%
# The Department of Education Statistics releases a data set annually containing the percentage of 
# bachelor's degrees granted to women from 1970 to 2012. The data set is broken up into 17 categories 
# of degrees, with each column as a separate category.

# In this mission and the next few missions, we'll explore how we can communicate the nuanced 
# narrative of gender gap using effective data visualization. Let's first generate a standard 
# matplotlib plot.

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %%
women_degrees = pd.read_csv('Dataquest/DataVis/percent-bachelors-degrees-women-usa.csv')

# %%
plt.plot(women_degrees['Year'], women_degrees['Biology'])
plt.show()

# %%
plt.plot(women_degrees['Year'], women_degrees['Biology'], c='blue', label='Women')
plt.plot(women_degrees['Year'], (100 - women_degrees['Biology']), c='green', label='Men')
plt.title('Percentage of Biology Degrees Awarded By Gender')
plt.legend(loc='upper right')
plt.show()

# %%
fig, ax = plt.subplots()

ax.tick_params(bottom='off', top='off', left='off', right='off')

plt.plot(women_degrees['Year'], women_degrees['Biology'], c='blue', label='Women')
plt.plot(women_degrees['Year'], (100 - women_degrees['Biology']), c='green', label='Men')
plt.title('Percentage of Biology Degrees Awarded By Gender')
plt.legend(loc='upper right')
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(women_degrees['Year'], women_degrees['Biology'], label='Women')
ax.plot(women_degrees['Year'], 100-women_degrees['Biology'], label='Men')
ax.tick_params(bottom="off", top="off", left="off", right="off")
# Add your code here
for spine in ax.spines:
    ax.spines[spine].set_visible(False)

ax.legend(loc='upper right')
ax.set_title('Percentage of Biology Degrees Awarded By Gender')
plt.show()

# %%
majors = ['Biology', 
          'Computer Science', 
          'Engineering', 
          'Math and Statistics']

fig = plt.figure(figsize=(12, 12))

for i in range(4):
    ax = fig.add_subplot(2, 2, i + 1)
    ax.plot(women_degrees['Year'], women_degrees[majors[i]], c='blue', label='Women')
    ax.plot(women_degrees['Year'], 100 - women_degrees[majors[i]], c='green', label='Men')
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0, 100)
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    ax.set_title(majors[i])
    
    for spine in ax.spines:
        ax.spines[spine].set_visible(False)

# Calling pyplot.legend() here will add the legend to the last subplot that was created.
plt.legend(loc='upper right')
plt.show()

# %%
# Selecting colors to be mindful about colorblindedness

cb_dark_blue = (0/255, 107/255, 164/255)
cb_orange = (255/255, 128/255, 14/255)
cb_light_blue = (162/255, 200/255, 236/255)
cb_red = (200/255, 82/255, 0/255)
cb_grey = (171/255, 171/255, 171/255)

# %%
fig = plt.figure(figsize=(12, 12))

for i in range(4):
    ax = fig.add_subplot(2, 2, i + 1)
    ax.plot(women_degrees['Year'], women_degrees[majors[i]], c=cb_dark_blue, label='Women')
    ax.plot(women_degrees['Year'], 100 - women_degrees[majors[i]], c=cb_orange, label='Men')
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0, 100)
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    ax.set_title(majors[i])
    
    for spine in ax.spines:
        ax.spines[spine].set_visible(False)

# Calling pyplot.legend() here will add the legend to the last subplot that was created.
plt.legend(loc='upper right')
plt.show()

# %%
# How to increase the linewidth (default is 2)

fig = plt.figure(figsize=(12, 12))

for i in range(4):
    ax = fig.add_subplot(2, 2, i + 1)
    ax.plot(women_degrees['Year'], women_degrees[majors[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100 - women_degrees[majors[i]], c=cb_orange, label='Men', linewidth=3)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0, 100)
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    ax.set_title(majors[i])
    
    for spine in ax.spines:
        ax.spines[spine].set_visible(False)

# Calling pyplot.legend() here will add the legend to the last subplot that was created.
plt.legend(loc='upper right')
plt.show()

# %%
# Plotting in descending order of gap for recent years. 

stem_majors = ['Engineering', 
               'Computer Science', 
               'Psychology', 
               'Biology', 
               'Physical Sciences', 
               'Math and Statistics']

fig = plt.figure(figsize=(18, 3)) # width, height

for i in range(6):
    ax = fig.add_subplot(1, 6, i + 1)
    ax.plot(women_degrees['Year'], women_degrees[stem_majors[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100 - women_degrees[stem_majors[i]], c=cb_orange, label='Men', linewidth=3)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0, 100)
    ax.set_title(stem_majors[i])
    ax.tick_params(bottom='off', top='off', left='off', right='off')
    
    for spine in ax.spines:
        ax.spines[spine].set_visible(False)

plt.legend(loc='upper right')
plt.show()

# %%
# Adding text annotations instead of a legend

fig = plt.figure(figsize=(18, 3)) # width, height

for i in range(6):
    ax = fig.add_subplot(1, 6, i + 1)
    ax.plot(women_degrees['Year'], women_degrees[stem_majors[i]], c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees['Year'], 100 - women_degrees[stem_majors[i]], c=cb_orange, linewidth=3)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0, 100)
    ax.set_title(stem_majors[i])
    ax.tick_params(bottom='off', top='off', left='off', right='off')
    
    if i == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    if i == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
        
    for spine in ax.spines:
        ax.spines[spine].set_visible(False)

plt.show()

# %%
# Majors ordered in descending order by the percentage of degrees awarded to women.

stem_cats = ['Psychology', 
             'Biology', 
             'Math and Statistics', 
             'Physical Sciences', 
             'Computer Science', 
             'Engineering', 
             'Computer Science']

lib_arts_cats = ['Foreign Languages', 
                 'English', 
                 'Communications and Journalism', 
                 'Art and Performance', 
                 'Social Sciences and History']

other_cats = ['Health Professions', 
              'Public Administration', 
              'Education', 
              'Agriculture',
              'Business', 
              'Architecture']

# %%
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering', 'Computer Science']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

fig = plt.figure(figsize=(15,15))

# STEM plots

for sp in range(6):
    ax = fig.add_subplot(6, 3, (3 * sp + 1))
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100 - women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.set_title(stem_cats[sp])
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.tick_params(bottom='off', top='off', left='off', right='off')
    if sp == 0:
        ax.text(2005, 12, 'Men')
        ax.text(2002, 90, 'Women')
    if sp == 5:
        ax.text(2005, 90, 'Men')
        ax.text(2002, 8, 'Women')
        
    for spine in ax.spines:
        ax.spines[spine].set_visible(False)

# Lib. Arts Plots
        
for sp in range(5):
    ax = fig.add_subplot(6, 3, (3 * sp + 2))
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100 - women_degrees[lib_arts_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.set_title(lib_arts_cats[sp])
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.tick_params(bottom='off', top='off', left='off', right='off')
    if sp == 0:
        ax.text(2005, 13, 'Men')
        ax.text(2002, 80, 'Women')
        
    for spine in ax.spines:
        ax.spines[spine].set_visible(False)

# Other plots
        
for sp in range(6):
    ax = fig.add_subplot(6, 3, (3 * sp + 3))
    ax.plot(women_degrees['Year'], women_degrees[other_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100 - women_degrees[other_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.set_title(other_cats[sp])
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.tick_params(bottom='off', top='off', left='off', right='off')
    if sp == 0:
        ax.text(2005, 3, 'Men')
        ax.text(2002, 90, 'Women')
    if sp == 5:
        ax.text(2005, 60, 'Men')
        ax.text(2002, 30, 'Women')
        
    for spine in ax.spines:
        ax.spines[spine].set_visible(False)

plt.show()

# %%
# Remove the x-axis labels except for the bottommost plots

stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering', 'Computer Science']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

fig = plt.figure(figsize=(15,15))

# STEM plots

for sp in range(6):
    ax = fig.add_subplot(6, 3, (3 * sp + 1))
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100 - women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.set_title(stem_cats[sp])
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.tick_params(bottom='off', top='off', left='off', right='off', labelbottom='off')
    if sp == 0:
        ax.text(2005, 12, 'Men')
        ax.text(2002, 90, 'Women')
    if sp == 5:
        ax.text(2005, 90, 'Men')
        ax.text(2002, 8, 'Women')
        ax.tick_params(labelbottom='on')
        
    for spine in ax.spines:
        ax.spines[spine].set_visible(False)

# Lib. Arts Plots
        
for sp in range(5):
    ax = fig.add_subplot(6, 3, (3 * sp + 2))
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100 - women_degrees[lib_arts_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.set_title(lib_arts_cats[sp])
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.tick_params(bottom='off', top='off', left='off', right='off', labelbottom='off')
    if sp == 0:
        ax.text(2005, 13, 'Men')
        ax.text(2002, 80, 'Women')
    if sp == 4:
        ax.tick_params(labelbottom='on')
        
    for spine in ax.spines:
        ax.spines[spine].set_visible(False)

# Other plots
        
for sp in range(6):
    ax = fig.add_subplot(6, 3, (3 * sp + 3))
    ax.plot(women_degrees['Year'], women_degrees[other_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100 - women_degrees[other_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.set_title(other_cats[sp])
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.tick_params(bottom='off', top='off', left='off', right='off', labelbottom='off')
    if sp == 0:
        ax.text(2005, 3, 'Men')
        ax.text(2002, 90, 'Women')
    if sp == 5:
        ax.text(2005, 60, 'Men')
        ax.text(2002, 30, 'Women')
        ax.tick_params(labelbottom='on')
        
    for spine in ax.spines:
        ax.spines[spine].set_visible(False)

plt.show()

# %%
# Show only 0 and 100 on the y-axis and add a horizontal line through the middle

stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering', 'Computer Science']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

fig = plt.figure(figsize=(15,15))

# STEM plots

for sp in range(6):
    ax = fig.add_subplot(6, 3, (3 * sp + 1))
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100 - women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.set_title(stem_cats[sp])
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0, 100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    ax.tick_params(bottom='off', top='off', left='off', right='off', labelbottom='off')
    if sp == 0:
        ax.text(2005, 12, 'Men')
        ax.text(2002, 90, 'Women')
    if sp == 5:
        ax.text(2005, 90, 'Men')
        ax.text(2002, 8, 'Women')
        ax.tick_params(labelbottom='on')
        
    for spine in ax.spines:
        ax.spines[spine].set_visible(False)

# Lib. Arts Plots
        
for sp in range(5):
    ax = fig.add_subplot(6, 3, (3 * sp + 2))
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100 - women_degrees[lib_arts_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.set_title(lib_arts_cats[sp])
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0, 100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    ax.tick_params(bottom='off', top='off', left='off', right='off', labelbottom='off')
    if sp == 0:
        ax.text(2005, 13, 'Men')
        ax.text(2002, 80, 'Women')
    if sp == 4:
        ax.tick_params(labelbottom='on')
        
    for spine in ax.spines:
        ax.spines[spine].set_visible(False)

# Other plots
        
for sp in range(6):
    ax = fig.add_subplot(6, 3, (3 * sp + 3))
    ax.plot(women_degrees['Year'], women_degrees[other_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100 - women_degrees[other_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.set_title(other_cats[sp])
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0, 100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    ax.tick_params(bottom='off', top='off', left='off', right='off', labelbottom='off')
    if sp == 0:
        ax.text(2005, 3, 'Men')
        ax.text(2002, 90, 'Women')
    if sp == 5:
        ax.text(2005, 60, 'Men')
        ax.text(2002, 30, 'Women')
        ax.tick_params(labelbottom='on')
        
    for spine in ax.spines:
        ax.spines[spine].set_visible(False)

plt.show()

# %%
# Show only 0 and 100 on the y-axis and add a horizontal line through the middle

stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering', 'Computer Science']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

fig = plt.figure(figsize=(15,15))

# STEM plots

for sp in range(6):
    ax = fig.add_subplot(6, 3, (3 * sp + 1))
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100 - women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.set_title(stem_cats[sp])
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0, 100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    ax.tick_params(bottom='off', top='off', left='off', right='off', labelbottom='off')
    if sp == 0:
        ax.text(2005, 12, 'Men')
        ax.text(2002, 90, 'Women')
    if sp == 5:
        ax.text(2005, 90, 'Men')
        ax.text(2002, 8, 'Women')
        ax.tick_params(labelbottom='on')
        
    for spine in ax.spines:
        ax.spines[spine].set_visible(False)

# Lib. Arts Plots
        
for sp in range(5):
    ax = fig.add_subplot(6, 3, (3 * sp + 2))
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100 - women_degrees[lib_arts_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.set_title(lib_arts_cats[sp])
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0, 100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    ax.tick_params(bottom='off', top='off', left='off', right='off', labelbottom='off')
    if sp == 0:
        ax.text(2005, 13, 'Men')
        ax.text(2002, 80, 'Women')
    if sp == 4:
        ax.tick_params(labelbottom='on')
        
    for spine in ax.spines:
        ax.spines[spine].set_visible(False)

# Other plots
        
for sp in range(6):
    ax = fig.add_subplot(6, 3, (3 * sp + 3))
    ax.plot(women_degrees['Year'], women_degrees[other_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100 - women_degrees[other_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.set_title(other_cats[sp])
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0, 100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    ax.tick_params(bottom='off', top='off', left='off', right='off', labelbottom='off')
    if sp == 0:
        ax.text(2005, 3, 'Men')
        ax.text(2002, 90, 'Women')
    if sp == 5:
        ax.text(2005, 60, 'Men')
        ax.text(2002, 30, 'Women')
        ax.tick_params(labelbottom='on')
        
    for spine in ax.spines:
        ax.spines[spine].set_visible(False)

plt.savefig('Dataquest/DataVis/gender_degrees.png')
plt.show()
